# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import sklearn.metrics as skm
import sklearn.model_selection as skms
import sklearn.preprocessing as skp
import random
import librosa, IPython
import librosa.display as lplt
seed = 12
np.random.seed(seed)

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#           filename       tempo  chroma_stft      rmse  spectral_centroid  \
# 0  blues.00000.wav  123.046875     0.349943  0.353032        1784.420446
# 1  blues.00001.wav   67.999589     0.340983  0.297381        1529.835316
# 2  blues.00002.wav  161.499023     0.363603  0.414141        1552.481958
# 3  blues.00003.wav   63.024009     0.404779  0.358998        1070.119953
# 4  blues.00004.wav  135.999178     0.308590  0.291960        1835.494603
#
#    spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0         2002.650192  3806.485316            0.083066 -113.596748
# 1         2038.617579  3548.820207            0.056044 -207.556793
# 2         1747.165985  3040.514948            0.076301  -90.754387
# 3         1596.333948  2185.028454            0.033309 -199.431152
# 4         1748.362448  3580.945013            0.101500 -160.266037
#
#         mfcc2  ...    mfcc12    mfcc13    mfcc14    mfcc15    mfcc16  \
# 0  121.557297  ...  8.810669 -3.667368  5.751691 -5.162763  0.750948
# 1  124.006721  ...  5.376803 -2.239120  4.216963 -6.012273  0.936109
# 2  140.459900  ...  5.789265 -8.905224 -1.083720 -9.218359  2.455806
# 3  150.099213  ...  6.087676 -2.476421 -1.073890 -2.874778  0.780977
# 4  126.198807  ... -2.806383 -6.934123 -7.558618 -9.173553 -4.512165
#
#      mfcc17    mfcc18    mfcc19     mfcc20  label
# 0 -1.691938 -0.409953 -2.300209   1.219929  blues
# 1 -0.716537  0.293876 -0.287431   0.531573  blues
# 2 -7.726901 -1.815723 -3.433434  -2.226821  blues
# 3 -3.316932  0.637982 -0.619690  -3.408233  blues
# 4 -5.453538 -0.924161 -4.409333 -11.703781  blues
#
# [5 rows x 29 columns]

# %%
print("Dataset has",df.shape)
print("Count of Positive and Negative samples")
df.label.value_counts().reset_index()
# Out:
# Dataset has (1499, 29)
# Count of Positive and Negative samples
#             index  label
# 0           blues    100
# 1        bollypop    100
# 2        carnatic    100
# 3       classical    100
# 4         country    100
# 5           disco    100
# 6          ghazal    100
# 7          hiphop    100
# 8           metal    100
# 9             pop    100
# 10         reggae    100
# 11           rock    100
# 12  semiclassical    100
# 13           sufi    100
# 14           jazz     99

# %%
audio_fp = 'Test Files_disco.wav'
audio_data, sr = librosa.load(audio_fp)
audio_data, _ = librosa.effects.trim(audio_data)

# %%
# play sample file
IPython.display.Audio(audio_data, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# plot sample file
plt.figure(figsize=(15,5))
lplt.waveshow(audio_data)
plt.show()

# %%
# Default FFT window size
n_fft = 2048 # window size
hop_length = 512 # window hop length for STFT

stft = librosa.stft(audio_data, n_fft=n_fft, hop_length=hop_length)
stft_db = librosa.amplitude_to_db(stft, ref=np.max)

plt.figure(figsize=(12,4))
lplt.specshow(stft, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()
plt.title("Spectrogram with amplitude")
plt.show()

plt.figure(figsize=(12,4))
lplt.specshow(stft_db, sr=sr, x_axis='time', y_axis='log', cmap='cool')
plt.colorbar()
plt.title("Spectrogram with decibel log")
plt.show()

# %%
# plot zoomed audio wave 
start = 1000
end = 1200
plt.figure(figsize=(16,4))
plt.plot(audio_data[start:end])
plt.show()

# %%
x = df[["label", "tempo"]]

fig, ax = plt.subplots(figsize=(18, 9));
sns.boxplot(x = "label", y = "tempo", data = x, palette = 'husl');

plt.title('BPM Boxplot for Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Genre", fontsize = 15)
plt.ylabel("BPM", fontsize = 15)
plt.savefig("BPM_Boxplot.png")

# %%
data = df.iloc[0:, 1:]
y = data['label']
X = data.loc[:, data.columns != 'label']

# normalize
cols = X.columns
min_max_scaler = skp.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X)
X = pd.DataFrame(np_scaled, columns = cols)

# Top 2 pca components
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])

# concatenate with target label
finalDf = pd.concat([principalDf, y], axis = 1)

plt.figure(figsize = (16, 9))
sns.scatterplot(x = "pc1", y = "pc2", data = finalDf, hue = "label", alpha = 0.7, s = 100);

plt.title('PCA on Genres', fontsize = 20)
plt.xticks(fontsize = 14)
plt.yticks(fontsize = 10);
plt.xlabel("Principal Component 1", fontsize = 15)
plt.ylabel("Principal Component 2", fontsize = 15)
plt.savefig("PCA_Scattert.png")

# %%
# find all columns with any NA values
print("Columns with NA values are",list(df.columns[df.isnull().any()]))
# Out:
# Columns with NA values are []

# %%
# map labels to index
label_index = dict()
index_label = dict()
for i, x in enumerate(df.label.unique()):
    label_index[x] = i
    index_label[i] = x
print(label_index)
print(index_label)
# Out:
# {'blues': 0, 'bollypop': 1, 'carnatic': 2, 'classical': 3, 'country': 4, 'disco': 5, 'ghazal': 6, 'hiphop': 7, 'jazz': 8, 'metal': 9, 'pop': 10, 'reggae': 11, 'rock': 12, 'semiclassical': 13, 'sufi': 14}
# {0: 'blues', 1: 'bollypop', 2: 'carnatic', 3: 'classical', 4: 'country', 5: 'disco', 6: 'ghazal', 7: 'hiphop', 8: 'jazz', 9: 'metal', 10: 'pop', 11: 'reggae', 12: 'rock', 13: 'semiclassical', 14: 'sufi'}

# %%
# update labels in df to index
df.label = [label_index[l] for l in df.label]

# %%
# shuffle samples
df_shuffle = df.sample(frac=1, random_state=seed).reset_index(drop=True)
print(df_shuffle)
# Out:
#                filename       tempo  chroma_stft      rmse  spectral_centroid  \
# 0              su11.wav   86.132812     0.291647  0.477633        1934.396165
# 1      reggae.00094.wav  129.199219     0.365591  0.363483        2022.436648
# 2     country.00033.wav   92.285156     0.316780  0.314188        2456.532022
# 3      reggae.00022.wav  151.999081     0.455355  0.423115        2059.310218
# 4              bp22.wav  107.666016     0.239319  0.455243        2131.229854
# ...                 ...         ...          ...       ...                ...
# 1494  country.00032.wav   99.384014     0.330975  0.235266        1823.306451
# 1495     rock.00084.wav  129.199219     0.356739  0.323865        2581.772682
# 1496     rock.00066.wav   75.999540     0.360098  0.193879        2209.357588
# 1497     rock.00078.wav   99.384014     0.358033  0.374754        1878.740319
# 1498           su15.wav  107.666016     0.333837  0.463335        2214.575121
#
#       spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0            2243.108374  4250.499298            0.086101  -69.082909
# 1            2129.499861  3834.226815            0.095666  -97.736404
# 2            2387.530598  4914.653615            0.123616 -133.308624
# 3            2227.055179  4552.830803            0.072342  -91.334671
# 4            2487.846025  4599.730519            0.080209  -96.559273
# ...                  ...          ...                 ...         ...
# 1494         2206.139275  4016.384047            0.067602 -237.970856
# 1495         2376.362209  5391.075734            0.139216  -94.275291
# 1496         2175.214294  4575.588999            0.107147 -245.160919
# 1497         2204.944115  4287.182409            0.071730 -131.050568
# 1498         2400.842451  5173.010386            0.101819  -50.812405
#
#            mfcc2  ...     mfcc12     mfcc13     mfcc14     mfcc15     mfcc16  \
# 0     110.921051  ...   1.755374  -4.498608   0.129791  -7.099224   3.495914
# 1     108.837486  ...   4.265133   2.458043  -6.628557  -3.160204  -1.099189
# 2      78.986084  ...  -1.171714  -4.816752  -3.142831  -5.046350  -1.091830
# 3      98.817696  ...  13.412445  -6.498818  14.025418   0.414114  12.586821
# 4      94.076630  ...  -1.721621 -11.297661   8.093388  -8.867827  -1.252377
# ...          ...  ...        ...        ...        ...        ...        ...
# 1494   97.709564  ...   3.022154  -1.662446  -5.420327  -2.828422  -3.053765
# 1495   91.881615  ...  13.336176 -15.462966   5.205345 -11.224630   6.211576
# 1496   95.089813  ...   0.813777 -13.018358   0.053167  -8.232850   1.059255
# 1497  110.947830  ...   9.195827  -6.963252   6.312277  -9.626780   0.505373
# 1498  102.739334  ...   7.562201  -6.095457   1.439751  -7.390719   6.258050
#
#          mfcc17     mfcc18     mfcc19     mfcc20  label
# 0    -10.398947   4.919723 -11.966673   0.197935     14
# 1     -4.834697  -0.117350  -7.432328  -7.704781     11
# 2     -0.958069  -2.449397   1.161944  -1.835098      4
# 3      0.345952  10.112188  -0.429141   1.291700     11
# 4    -12.349724  -0.095951  -9.081445   4.772449      1
# ...         ...        ...        ...        ...    ...
# 1494  -0.498209  -0.107862  -3.856138  -2.652332      4
# 1495  -7.955702   7.708806  -4.608233   0.528086     12
# 1496  -8.031864  -0.397097  -4.349921  -4.220999     12
# 1497 -12.774693  -4.904711  -2.517012  -3.125299     12
# 1498  -7.472842  -0.483730  -7.769357 -12.369685     14
#
# [1499 rows x 29 columns]

# %%
# remove irrelevant columns
df_shuffle.drop(['filename'], axis=1, inplace=True)
df_y = df_shuffle.pop('label')
df_X = df_shuffle

# split into train dev and test
X_train, df_test_valid_X, y_train, df_test_valid_y = skms.train_test_split(df_X, df_y, train_size=0.7, random_state=seed, stratify=df_y)
X_dev, X_test, y_dev, y_test = skms.train_test_split(df_test_valid_X, df_test_valid_y, train_size=0.66, random_state=seed, stratify=df_test_valid_y)

# %%
print(f"Train set has {X_train.shape[0]} records out of {len(df_shuffle)} which is {round(X_train.shape[0]/len(df_shuffle)*100)}%")
print(f"Dev set has {X_dev.shape[0]} records out of {len(df_shuffle)} which is {round(X_dev.shape[0]/len(df_shuffle)*100)}%")
print(f"Test set has {X_test.shape[0]} records out of {len(df_shuffle)} which is {round(X_test.shape[0]/len(df_shuffle)*100)}%")
# Out:
# Train set has 1049 records out of 1499 which is 70%
# Dev set has 297 records out of 1499 which is 20%
# Test set has 153 records out of 1499 which is 10%

# %%
print(y_train.value_counts()[0]/y_train.shape[0]*100)
print(y_dev.value_counts()[0]/y_dev.shape[0]*100)
print(y_test.value_counts()[0]/y_test.shape[0]*100)
# Out:
# 6.67302192564347
# 6.7340067340067336
# 6.535947712418301

# %%
scaler = skp.StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_dev = pd.DataFrame(scaler.transform(X_dev), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_train.columns)

# %%
import tensorflow as tf
print("TF version:-", tf.__version__)
import keras as k
tf.random.set_seed(seed)
# Out:
# TF version:- 2.12.0

# %%
ACCURACY_THRESHOLD = 0.72

class myCallback(k.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
            print("\n\nStopping training as we have reached %2.2f%% accuracy!" %(ACCURACY_THRESHOLD*100))   
            self.model.stop_training = True

def trainModel(model, epochs, optimizer):
    batch_size = 128
    callback = myCallback()
    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics='accuracy'
    )
    return model.fit(X_train, y_train, validation_data=(X_dev, y_dev), epochs=epochs, 
                     batch_size=batch_size, callbacks=[callback])

def plotHistory(history):
    print("Max. Validation Accuracy",max(history.history["val_accuracy"]))
    pd.DataFrame(history.history).plot(figsize=(12,6))
    plt.show()

# %%
model_1 = k.models.Sequential([
    k.layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    k.layers.Dropout(0.2),
    k.layers.Dense(128, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(64, activation='relu'),
    k.layers.Dropout(0.2),
    k.layers.Dense(15, activation='softmax'),
])
print(model_1.summary())
model_1_history = trainModel(model=model_1, epochs=150, optimizer='adam')
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 256)               7168
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 128)               32896
#
#  dropout_22 (Dropout)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 64)                8256
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_31 (Dense)            (None, 15)                975
#
# =================================================================
# Total params: 49,295
# Trainable params: 49,295
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/150
# 9/9 [==============================] - 1s 29ms/step - loss: 2.6499 - accuracy: 0.1220 - val_loss: 2.4387 - val_accuracy: 0.2761
# Epoch 2/150
# 9/9 [==============================] - 0s 10ms/step - loss: 2.3983 - accuracy: 0.2574 - val_loss: 2.2019 - val_accuracy: 0.3131
# Epoch 3/150
# 9/9 [==============================] - 0s 9ms/step - loss: 2.1740 - accuracy: 0.3022 - val_loss: 1.9896 - val_accuracy: 0.3502
# Epoch 4/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.9899 - accuracy: 0.3756 - val_loss: 1.7888 - val_accuracy: 0.4074
# Epoch 5/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.8376 - accuracy: 0.3861 - val_loss: 1.6318 - val_accuracy: 0.4377
# Epoch 6/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.7222 - accuracy: 0.4061 - val_loss: 1.5098 - val_accuracy: 0.4512
# Epoch 7/150
# 9/9 [==============================] - 0s 9ms/step - loss: 1.5959 - accuracy: 0.4509 - val_loss: 1.4320 - val_accuracy: 0.4949
# Epoch 8/150
# 9/9 [==============================] - 0s 8ms/step - loss: 1.5399 - accuracy: 0.4862 - val_loss: 1.3636 - val_accuracy: 0.5286
# Epoch 9/150
# 9/9 [==============================] - 0s 12ms/step - loss: 1.4494 - accuracy: 0.5119 - val_loss: 1.3183 - val_accuracy: 0.5589
# Epoch 10/150
# 9/9 [==============================] - 0s 11ms/step - loss: 1.3512 - accuracy: 0.5415 - val_loss: 1.2779 - val_accuracy: 0.5791
# Epoch 11/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.3497 - accuracy: 0.5319 - val_loss: 1.2401 - val_accuracy: 0.5657
# Epoch 12/150
# 9/9 [==============================] - 0s 9ms/step - loss: 1.3018 - accuracy: 0.5415 - val_loss: 1.2080 - val_accuracy: 0.5892
# Epoch 13/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.2995 - accuracy: 0.5491 - val_loss: 1.1820 - val_accuracy: 0.6195
# Epoch 14/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.2128 - accuracy: 0.5767 - val_loss: 1.1681 - val_accuracy: 0.6128
# Epoch 15/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.1595 - accuracy: 0.5872 - val_loss: 1.1524 - val_accuracy: 0.6229
# Epoch 16/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.1677 - accuracy: 0.6006 - val_loss: 1.1202 - val_accuracy: 0.6330
# Epoch 17/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.1362 - accuracy: 0.6044 - val_loss: 1.1092 - val_accuracy: 0.6431
# Epoch 18/150
# 9/9 [==============================] - 0s 8ms/step - loss: 1.0965 - accuracy: 0.6034 - val_loss: 1.1189 - val_accuracy: 0.6566
# Epoch 19/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0945 - accuracy: 0.6292 - val_loss: 1.0904 - val_accuracy: 0.6498
# Epoch 20/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0389 - accuracy: 0.6339 - val_loss: 1.0817 - val_accuracy: 0.6330
# Epoch 21/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0175 - accuracy: 0.6654 - val_loss: 1.0775 - val_accuracy: 0.6566
# Epoch 22/150
# 9/9 [==============================] - 0s 10ms/step - loss: 1.0010 - accuracy: 0.6454 - val_loss: 1.0627 - val_accuracy: 0.6330
# Epoch 23/150
# 9/9 [==============================] - 0s 11ms/step - loss: 1.0111 - accuracy: 0.6492 - val_loss: 1.0663 - val_accuracy: 0.6330
# Epoch 24/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9664 - accuracy: 0.6540 - val_loss: 1.0813 - val_accuracy: 0.6229
# Epoch 25/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.9639 - accuracy: 0.6616 - val_loss: 1.0653 - val_accuracy: 0.6364
# Epoch 26/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9296 - accuracy: 0.6711 - val_loss: 1.0525 - val_accuracy: 0.6498
# Epoch 27/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.9230 - accuracy: 0.6711 - val_loss: 1.0404 - val_accuracy: 0.6768
# Epoch 28/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.9139 - accuracy: 0.6826 - val_loss: 1.0206 - val_accuracy: 0.6835
# Epoch 29/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8939 - accuracy: 0.6826 - val_loss: 1.0248 - val_accuracy: 0.6700
# Epoch 30/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.8755 - accuracy: 0.6969 - val_loss: 1.0145 - val_accuracy: 0.6599
# Epoch 31/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.8540 - accuracy: 0.6959 - val_loss: 1.0137 - val_accuracy: 0.6633
# Epoch 32/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.8293 - accuracy: 0.6930 - val_loss: 1.0241 - val_accuracy: 0.6700
# Epoch 33/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8355 - accuracy: 0.7131 - val_loss: 1.0146 - val_accuracy: 0.6667
# Epoch 34/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8304 - accuracy: 0.7083 - val_loss: 1.0312 - val_accuracy: 0.6700
# Epoch 35/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8348 - accuracy: 0.7073 - val_loss: 1.0294 - val_accuracy: 0.6566
# Epoch 36/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.8103 - accuracy: 0.7016 - val_loss: 1.0213 - val_accuracy: 0.6667
# Epoch 37/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7806 - accuracy: 0.7178 - val_loss: 1.0275 - val_accuracy: 0.6599
# Epoch 38/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7631 - accuracy: 0.7283 - val_loss: 1.0248 - val_accuracy: 0.6801
# Epoch 39/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7487 - accuracy: 0.7388 - val_loss: 1.0053 - val_accuracy: 0.6768
# Epoch 40/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7260 - accuracy: 0.7493 - val_loss: 1.0062 - val_accuracy: 0.6768
# Epoch 41/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7499 - accuracy: 0.7426 - val_loss: 1.0147 - val_accuracy: 0.6835
# Epoch 42/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6926 - accuracy: 0.7483 - val_loss: 1.0050 - val_accuracy: 0.6768
# Epoch 43/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7400 - accuracy: 0.7388 - val_loss: 1.0103 - val_accuracy: 0.6768
# Epoch 44/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.7029 - accuracy: 0.7541 - val_loss: 1.0102 - val_accuracy: 0.6801
# Epoch 45/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.7041 - accuracy: 0.7531 - val_loss: 1.0052 - val_accuracy: 0.6667
# Epoch 46/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.7365 - accuracy: 0.7560 - val_loss: 1.0136 - val_accuracy: 0.6801
# Epoch 47/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6663 - accuracy: 0.7521 - val_loss: 1.0132 - val_accuracy: 0.6801
# Epoch 48/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6526 - accuracy: 0.7836 - val_loss: 0.9986 - val_accuracy: 0.6835
# Epoch 49/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.6645 - accuracy: 0.7731 - val_loss: 1.0002 - val_accuracy: 0.6734
# Epoch 50/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.6399 - accuracy: 0.7769 - val_loss: 1.0089 - val_accuracy: 0.6667
# Epoch 51/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.6452 - accuracy: 0.7817 - val_loss: 1.0171 - val_accuracy: 0.6768
# Epoch 52/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6305 - accuracy: 0.7855 - val_loss: 1.0149 - val_accuracy: 0.6902
# Epoch 53/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.6260 - accuracy: 0.7798 - val_loss: 1.0301 - val_accuracy: 0.6667
# Epoch 54/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.6227 - accuracy: 0.7817 - val_loss: 1.0319 - val_accuracy: 0.6532
# Epoch 55/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5795 - accuracy: 0.8046 - val_loss: 1.0477 - val_accuracy: 0.6801
# Epoch 56/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5916 - accuracy: 0.7979 - val_loss: 1.0074 - val_accuracy: 0.6734
# Epoch 57/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5978 - accuracy: 0.7950 - val_loss: 1.0141 - val_accuracy: 0.6801
# Epoch 58/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5748 - accuracy: 0.7865 - val_loss: 1.0330 - val_accuracy: 0.6835
# Epoch 59/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5790 - accuracy: 0.7979 - val_loss: 1.0462 - val_accuracy: 0.6700
# Epoch 60/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5582 - accuracy: 0.8151 - val_loss: 1.0446 - val_accuracy: 0.6869
# Epoch 61/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5583 - accuracy: 0.7950 - val_loss: 1.0026 - val_accuracy: 0.6902
# Epoch 62/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5587 - accuracy: 0.8055 - val_loss: 0.9887 - val_accuracy: 0.6700
# Epoch 63/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5552 - accuracy: 0.8170 - val_loss: 1.0324 - val_accuracy: 0.6902
# Epoch 64/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5365 - accuracy: 0.7998 - val_loss: 1.0023 - val_accuracy: 0.6902
# Epoch 65/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.5076 - accuracy: 0.8265 - val_loss: 1.0184 - val_accuracy: 0.6869
# Epoch 66/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.5077 - accuracy: 0.8332 - val_loss: 1.0245 - val_accuracy: 0.6869
# Epoch 67/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.5353 - accuracy: 0.8132 - val_loss: 1.0321 - val_accuracy: 0.6902
# Epoch 68/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5150 - accuracy: 0.8255 - val_loss: 1.0326 - val_accuracy: 0.6801
# Epoch 69/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4927 - accuracy: 0.8284 - val_loss: 1.0211 - val_accuracy: 0.6801
# Epoch 70/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4926 - accuracy: 0.8246 - val_loss: 1.0247 - val_accuracy: 0.6936
# Epoch 71/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4977 - accuracy: 0.8179 - val_loss: 1.0451 - val_accuracy: 0.6768
# Epoch 72/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.5223 - accuracy: 0.8160 - val_loss: 1.0411 - val_accuracy: 0.6902
# Epoch 73/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4896 - accuracy: 0.8303 - val_loss: 1.0208 - val_accuracy: 0.7071
# Epoch 74/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.4641 - accuracy: 0.8332 - val_loss: 1.0283 - val_accuracy: 0.6835
# Epoch 75/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4570 - accuracy: 0.8570 - val_loss: 1.0463 - val_accuracy: 0.7037
# Epoch 76/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4513 - accuracy: 0.8408 - val_loss: 1.0690 - val_accuracy: 0.6970
# Epoch 77/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4650 - accuracy: 0.8341 - val_loss: 1.0681 - val_accuracy: 0.6936
# Epoch 78/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4364 - accuracy: 0.8561 - val_loss: 1.0486 - val_accuracy: 0.6902
# Epoch 79/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4617 - accuracy: 0.8389 - val_loss: 1.0629 - val_accuracy: 0.6734
# Epoch 80/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4529 - accuracy: 0.8475 - val_loss: 1.0802 - val_accuracy: 0.6768
# Epoch 81/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4457 - accuracy: 0.8465 - val_loss: 1.0573 - val_accuracy: 0.6835
# Epoch 82/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4172 - accuracy: 0.8551 - val_loss: 1.0370 - val_accuracy: 0.6970
# Epoch 83/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4140 - accuracy: 0.8646 - val_loss: 1.0394 - val_accuracy: 0.7037
# Epoch 84/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4332 - accuracy: 0.8503 - val_loss: 1.0396 - val_accuracy: 0.7003
# Epoch 85/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4229 - accuracy: 0.8627 - val_loss: 1.0303 - val_accuracy: 0.6801
# Epoch 86/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4314 - accuracy: 0.8580 - val_loss: 1.0447 - val_accuracy: 0.7003
# Epoch 87/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4041 - accuracy: 0.8551 - val_loss: 1.0616 - val_accuracy: 0.6902
# Epoch 88/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3885 - accuracy: 0.8656 - val_loss: 1.0517 - val_accuracy: 0.6869
# Epoch 89/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.4046 - accuracy: 0.8684 - val_loss: 1.0751 - val_accuracy: 0.7071
# Epoch 90/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3999 - accuracy: 0.8589 - val_loss: 1.0689 - val_accuracy: 0.6768
# Epoch 91/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3638 - accuracy: 0.8789 - val_loss: 1.0477 - val_accuracy: 0.7003
# Epoch 92/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3885 - accuracy: 0.8665 - val_loss: 1.0658 - val_accuracy: 0.7138
# Epoch 93/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3941 - accuracy: 0.8665 - val_loss: 1.0670 - val_accuracy: 0.6970
# Epoch 94/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3917 - accuracy: 0.8723 - val_loss: 1.0843 - val_accuracy: 0.7003
# Epoch 95/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3726 - accuracy: 0.8742 - val_loss: 1.0669 - val_accuracy: 0.6835
# Epoch 96/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3441 - accuracy: 0.8866 - val_loss: 1.0697 - val_accuracy: 0.7003
# Epoch 97/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3603 - accuracy: 0.8713 - val_loss: 1.0535 - val_accuracy: 0.6835
# Epoch 98/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3320 - accuracy: 0.8885 - val_loss: 1.0464 - val_accuracy: 0.6835
# Epoch 99/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3280 - accuracy: 0.8904 - val_loss: 1.0463 - val_accuracy: 0.7003
# Epoch 100/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3339 - accuracy: 0.8913 - val_loss: 1.0657 - val_accuracy: 0.6902
# Epoch 101/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.3524 - accuracy: 0.8894 - val_loss: 1.0888 - val_accuracy: 0.6801
# Epoch 102/150
# 1/9 [==>...........................] - ETA: 0s - loss: 0.3050 - accuracy: 0.9141
#
# Stopping training as we have reached 72.00% accuracy!
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3235 - accuracy: 0.8970 - val_loss: 1.1108 - val_accuracy: 0.7205

# %%
plotHistory(model_1_history)
# Out:
# Max. Validation Accuracy 0.7205387353897095

# %%
test_loss, test_acc = model_1.evaluate(X_test,y_test)
print("Test loss:",test_loss,"\nTest accuracy",test_acc)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7245 - accuracy: 0.7778
# Test loss: 0.7245160937309265
# Test accuracy 0.7777777910232544

# %%
def getmetadata(filename):
    import librosa
    import numpy as np


    y, sr = librosa.load(filename)
    #fetching tempo
    tempo, beat_frames = librosa.beat.beat_track(y=y, sr=sr)
    beat_times = librosa.frames_to_time(beat_frames, sr=sr)
    beat_times

    #chroma_stft

    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)

    #rmse

    rmse = librosa.feature.rms(y=y)

    #fetching spectral centroid

    spec_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)[0]

    #spectral bandwidth

    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)

    #fetching spectral rolloff

    spec_rolloff = librosa.feature.spectral_rolloff(y=y+0.01, sr=sr)[0]

    #zero crossing rate

    zero_crossing = librosa.feature.zero_crossing_rate(y)

    #mfcc

    mfcc = librosa.feature.mfcc(y=y, sr=sr)

    #metadata dictionary

    metadata_dict = {'tempo':np.mean(beat_times),'chroma_stft':np.mean(chroma_stft),'rmse':np.mean(rmse),
                     'spectral_centroid':np.mean(spec_centroid),'spectral_bandwidth':np.mean(spec_bw), 
                     'rolloff':np.mean(spec_rolloff), 'zero_crossing_rate':np.mean(zero_crossing)}

    for i in range(1,21):
        metadata_dict.update({'mfcc'+str(i):np.mean(mfcc[i-1])})

    return list(metadata_dict.values())

# %%
new_audio = 'Test Files_disco.wav'
audio_data1, sr1 = librosa.load(new_audio)
audio_data1, _ = librosa.effects.trim(audio_data1)

# %%
arr = getmetadata(new_audio)
arr
# Out:
# [14.404567160197413,
#  0.42159122,
#  0.17077067,
#  3391.3650851073285,
#  3108.93319540748,
#  7180.124177512326,
#  0.1595289992991106,
#  -40.076855,
#  56.219803,
#  23.692863,
#  31.93953,
#  2.4548008,
#  2.5702758,
#  -2.4864345,
#  3.1007562,
#  1.8817089,
#  3.3470368,
#  -0.0018149108,
#  -1.5163457,
#  -2.451519,
#  -5.074228,
#  -3.6787608,
#  -7.8542776,
#  -3.0474572,
#  -2.7854023,
#  -7.4963384,
#  -3.6242175]

# %%
m = pd.DataFrame(scaler.fit_transform([arr]))
ynew = model_1.predict([m])
print(ynew)
# Out:
# 1/1 [==============================] - 0s 217ms/step
# [[0.03121156 0.02000324 0.03764591 0.04207461 0.11855531 0.13356587
#   0.16114181 0.0552063  0.08610534 0.02333465 0.04641661 0.0690872
#   0.07050211 0.05046926 0.05468028]]

# %%
predictions = model_1.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 4ms/step

# %%
predictions[0].shape
# Out:
# (15,)

# %%
np.sum(predictions[0])
# Out:
# 1.0

# %%
df = pd.DataFrame()
df["predictions"] = np.argmax(predictions,axis=1)
adjusted_y_test = y_test.reset_index(drop=True)
df["actual labels"] = adjusted_y_test
df
# Out:
#      predictions  actual labels
# 0              5              5
# 1              8              8
# 2             12             12
# 3             10             10
# 4              0              0
# ..           ...            ...
# 148            4              5
# 149            8              8
# 150            2              2
# 151           10              7
# 152            9              9
#
# [153 rows x 2 columns]

# %%
model_1.save('model.h5')
